# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.python.keras.models import Sequential,model_from_json
from tensorflow.python.keras.preprocessing import image
from tensorflow.keras.callbacks            import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.python.keras.layers import Activation, Dropout, Flatten, Dense
from keras.applications import VGG16
from tensorflow.python.keras.optimizers import Adam
import numpy as np
from google.colab import files
import os 
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import os
import zipfile
import cv2
import shutil
import random
import pandas as pd
from matplotlib.image import imread
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## UPLOADING FILES
#
# ---

# %%
file = files.upload()
p = os.path.abspath('kaggle.json')
print(p)
# Out:
#      <input type="file" id="files-ff9e4f1b-28a1-406a-aa37-025031894a1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff9e4f1b-28a1-406a-aa37-025031894a1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# /content/kaggle.json

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.9)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)

# %%
# !mkdir ~/.kaggle
p = os.path.abspath('.kaggle')
print(p)
# !ls
# Out:
# /content/.kaggle
# kaggle.json  sample_data

# %%
# !mv /content/kaggle.json ~/.kaggle
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading test1.zip to /content
#  96% 261M/271M [00:06<00:00, 40.8MB/s]
# 100% 271M/271M [00:06<00:00, 44.1MB/s]
# Downloading train.zip to /content
#  99% 539M/543M [00:10<00:00, 79.7MB/s]
# 100% 543M/543M [00:10<00:00, 54.4MB/s]
# Downloading sampleSubmission.csv to /content
#   0% 0.00/86.8k [00:00<?, ?B/s]
# 100% 86.8k/86.8k [00:00<00:00, 84.2MB/s]

# %%
# !unzip '/content/test1.zip'
# !unzip '/content/train.zip'

# %% [markdown]
# ## Data Preparation
#
# ---

# %%
# Каталог с набором данных
data_dir = '/content/train'
# Каталог с данными для обучения
train_dir = 'train01'
test_sub = 'final-dataset'
# Каталог с данными для проверки
val_dir = 'val'
# Каталог с данными для тестирования
test_dir = 'test01'
# Часть набора данных для тестирования
test_data_portion = 0.15
# Часть набора данных для проверки
val_data_portion = 0.15
# Количество элементов данных в одном классе
nb_images = 12500

# %%
def create_directory(dir_name):
    if os.path.exists(dir_name):
        shutil.rmtree(dir_name)
    os.makedirs(dir_name)
    os.makedirs(os.path.join(dir_name, "cats"))
    os.makedirs(os.path.join(dir_name, "dogs"))

# %%
create_directory(train_dir)
create_directory(val_dir)
create_directory(test_sub)
create_directory(test_dir)

# %%
def copy_images(start_index, end_index, source_dir, dest_dir):
    for i in range(start_index, end_index):
        shutil.copy2(os.path.join(source_dir, "cat." + str(i) + ".jpg"), 
                    os.path.join(dest_dir, "cats"))
        shutil.copy2(os.path.join(source_dir, "dog." + str(i) + ".jpg"), 
                   os.path.join(dest_dir, "dogs"))

# %%
final_data = int(nb_images * 0.5)
start_val_data_idx = int(nb_images * (1 - val_data_portion - test_data_portion))
start_test_data_idx = int(nb_images * (1 - test_data_portion))
print(start_val_data_idx)
print(final_data)
print(start_test_data_idx)
# Out:
# 8750
# 6250
# 10625

# %%
test = '/content/test1'
copy_images(0, final_data, data_dir, test_sub)
copy_images(0, start_val_data_idx, data_dir, train_dir)
copy_images(start_val_data_idx, start_test_data_idx, data_dir, val_dir)
copy_images(start_test_data_idx, nb_images, data_dir, test_dir)

# %%
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)
batch_size = 10
nb_train_samples = 17500
nb_validation_samples = 3750
nb_test_samples = 3750

# %%
# define location of dataset
folder = '/content/train/'
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# define filename
	filename = folder + 'dog.' + str(i) + '.jpg'
	# load image pixels
	image = imread(filename)
	# plot raw pixel data
	plt.imshow(image)
# show the figure
plt.show()

# %% [markdown]
# ## Creating model
#
# ---
#
#
#
# ---

# %%
vgg16_net = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 5s 0us/step

# %%
datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_dir = '/content/train01'
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_width,img_height),
    batch_size=batch_size,
    class_mode=None,
    shuffle=False)
# Out:
# Found 17500 images belonging to 2 classes.

# %%
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode=None,
    shuffle=False)
# Out:
# Found 3750 images belonging to 2 classes.

# %%
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode=None,
    shuffle=False)
# Out:
# Found 3750 images belonging to 2 classes.

# %%
features_train = vgg16_net.predict_generator(
        train_generator, 
        nb_train_samples // batch_size)
np.save(open('/content/features_train.npy', 'wb'), features_train)

# %%
features_val = vgg16_net.predict_generator(
        val_generator, nb_validation_samples // batch_size)
np.save(open('/content/features_val.npy', 'wb'), features_val)

# %%
features_test = vgg16_net.predict_generator(
        test_generator, nb_test_samples // batch_size)
np.save(open('/content/features_test.npy', 'wb'), features_test)

# %%
labels_train =  np.array(
        [0] * (nb_train_samples // 2) + [1] * (nb_train_samples // 2))
labels_val =  np.array(
        [0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))
labels_test =  np.array(
        [0] * (nb_test_samples // 2) + [1] * (nb_test_samples // 2))

# %%
features_train = np.load(open('features_train.npy', 'rb'))
features_val = np.load(open('features_val.npy', 'rb'))
features_test = np.load(open('features_test.npy', 'rb'))

# %%
def model_init_():
  model = Sequential()
  model.add(Flatten(input_shape=features_train.shape[1:]))
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))
  return model
model = model_init_()

# %%
model.compile(optimizer='Adam',
              loss='binary_crossentropy', metrics=['accuracy'])

# %%
сheckpoint = ModelCheckpoint('content/mnist-cnn.h5', 
                              monitor='val_acc', 
                              save_best_only=True,
                              verbose=1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
history = model.fit(features_train, labels_train,
              epochs=30,
              batch_size=64,
              validation_data=(features_val, labels_val), 
              verbose=2,
              callbacks=[сheckpoint, learning_rate_reduction])
# Out:
# Epoch 1/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.3344 - accuracy: 0.8647 - val_loss: 0.2632 - val_accuracy: 0.8883 - lr: 0.0010
# Epoch 2/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.2260 - accuracy: 0.9015 - val_loss: 0.2149 - val_accuracy: 0.9147 - lr: 0.0010
# Epoch 3/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.2022 - accuracy: 0.9161 - val_loss: 0.2371 - val_accuracy: 0.8955 - lr: 0.0010
# Epoch 4/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1924 - accuracy: 0.9189 - val_loss: 0.2099 - val_accuracy: 0.9152 - lr: 0.0010
# Epoch 5/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1770 - accuracy: 0.9242 - val_loss: 0.2236 - val_accuracy: 0.9091 - lr: 0.0010
# Epoch 6/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1591 - accuracy: 0.9339 - val_loss: 0.2018 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 7/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1436 - accuracy: 0.9417 - val_loss: 0.2006 - val_accuracy: 0.9163 - lr: 0.0010
# Epoch 8/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1346 - accuracy: 0.9450 - val_loss: 0.2109 - val_accuracy: 0.9173 - lr: 0.0010
# Epoch 9/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1236 - accuracy: 0.9503 - val_loss: 0.2186 - val_accuracy: 0.9139 - lr: 0.0010
# Epoch 10/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1189 - accuracy: 0.9510 - val_loss: 0.2202 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 11/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.1103 - accuracy: 0.9549 - val_loss: 0.2249 - val_accuracy: 0.9168 - lr: 0.0010
# Epoch 12/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0966 - accuracy: 0.9613 - val_loss: 0.2208 - val_accuracy: 0.9208 - lr: 0.0010
# Epoch 13/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0845 - accuracy: 0.9666 - val_loss: 0.2451 - val_accuracy: 0.9205 - lr: 0.0010
# Epoch 14/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0842 - accuracy: 0.9667 - val_loss: 0.3400 - val_accuracy: 0.8973 - lr: 0.0010
# Epoch 15/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0812 - accuracy: 0.9677 - val_loss: 0.2423 - val_accuracy: 0.9203 - lr: 0.0010
# Epoch 16/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0733 - accuracy: 0.9710 - val_loss: 0.2775 - val_accuracy: 0.9179 - lr: 0.0010
# Epoch 17/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0619 - accuracy: 0.9755 - val_loss: 0.2868 - val_accuracy: 0.9149 - lr: 0.0010
# Epoch 18/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0602 - accuracy: 0.9773 - val_loss: 0.2708 - val_accuracy: 0.9171 - lr: 0.0010
# Epoch 19/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0520 - accuracy: 0.9797 - val_loss: 0.2956 - val_accuracy: 0.9189 - lr: 0.0010
# Epoch 20/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0576 - accuracy: 0.9774 - val_loss: 0.2877 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 21/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0593 - accuracy: 0.9767 - val_loss: 0.2944 - val_accuracy: 0.9227 - lr: 0.0010
# Epoch 22/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0680 - accuracy: 0.9720 - val_loss: 0.2838 - val_accuracy: 0.9192 - lr: 0.0010
# Epoch 23/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0446 - accuracy: 0.9836 - val_loss: 0.3540 - val_accuracy: 0.9203 - lr: 0.0010
# Epoch 24/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0455 - accuracy: 0.9826 - val_loss: 0.3199 - val_accuracy: 0.9184 - lr: 0.0010
# Epoch 25/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0444 - accuracy: 0.9825 - val_loss: 0.3522 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 26/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0482 - accuracy: 0.9813 - val_loss: 0.3475 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 27/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0465 - accuracy: 0.9814 - val_loss: 0.3613 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 28/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0401 - accuracy: 0.9852 - val_loss: 0.3863 - val_accuracy: 0.9179 - lr: 0.0010
# Epoch 29/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0340 - accuracy: 0.9869 - val_loss: 0.3645 - val_accuracy: 0.9208 - lr: 0.0010
# Epoch 30/30
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 274/274 - 2s - loss: 0.0344 - accuracy: 0.9867 - val_loss: 0.3619 - val_accuracy: 0.9171 - lr: 0.0010

# %%
model.save('/content/model01.h5')

# %%
def plot_model_history(model_history, acc='accuracy', val_acc='val_accuracy'):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    axs[0].plot(range(1,len(model_history.history[acc])+1),model_history.history[acc])
    axs[0].plot(range(1,len(model_history.history[val_acc])+1),model_history.history[val_acc])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history[acc])+1),len(model_history.history[acc])/10)
    axs[0].legend(['train', 'val'], loc='best')
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()
    
plot_model_history(history)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   from ipykernel import kernelapp as app

# %%
scores = model.evaluate(features_test, labels_test, verbose=1)
print("Аккуратность на тестовых данных: %.2f%%" % (scores[1]*100))
# Out:
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3644 - accuracy: 0.9117
# Аккуратность на тестовых данных: 91.17%
